# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("BoomBikes.csv")
data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        1           1
# 1          2  02-01-2018       1   0     1        0        2           1
# 2          3  03-01-2018       1   0     1        0        3           1
# 3          4  04-01-2018       1   0     1        0        4           1
# 4          5  05-01-2018       1   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        5           1
# 726      727  28-12-2019       1   1    12        0        6           0
# 727      728  29-12-2019       1   1    12        0        0           0
# 728      729  30-12-2019       1   1    12        0        1           1
# 729      730  31-12-2019       1   1    12        0        2           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
sns.kdeplot(data['temp'])
sns.histplot(data['temp'], alpha=0.45, stat='density', edgecolor=None)
# Out:
# <Axes: xlabel='temp', ylabel='Density'>

# %%
sns.kdeplot(data['atemp'])
sns.histplot(data['atemp'], alpha=0.45, stat='density', edgecolor=None)
# Out:
# <Axes: xlabel='atemp', ylabel='Density'>

# %%
sns.kdeplot(data['windspeed'])
sns.histplot(data['windspeed'], stat='density', edgecolor=None, alpha=0.45)
# Out:
# <Axes: xlabel='windspeed', ylabel='Density'>

# %%
sns.kdeplot(data['cnt'])
sns.histplot(data['cnt'], alpha=0.45, stat='density', edgecolor=None)
# Out:
# <Axes: xlabel='cnt', ylabel='Density'>

# %%
data['dteday'] = data['dteday'].astype('datetime64[s]')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    datetime64[s]
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: datetime64[s](1), float64(4), int64(11)
# memory usage: 91.4 KB

# %%
sns.boxplot(x='season', y='cnt', data=data, hue='season')
# Out:
# <Axes: xlabel='season', ylabel='cnt'>

# %%
sns.boxplot(x='mnth', y='cnt', data=data, hue='mnth')
# Out:
# <Axes: xlabel='mnth', ylabel='cnt'>

# %%
sns.boxplot(x='weekday', y='cnt', data=data, hue='weekday')
# Out:
# <Axes: xlabel='weekday', ylabel='cnt'>

# %%
sns.boxplot(x='weathersit', y='cnt', data=data, hue='weathersit')
# Out:
# <Axes: xlabel='weathersit', ylabel='cnt'>

# %%
sns.boxplot(x='workingday', y='cnt', data=data, hue='workingday')
# Out:
# <Axes: xlabel='workingday', ylabel='cnt'>

# %%
sns.boxplot(x='holiday', y='cnt', data=data, hue='holiday')
# Out:
# <Axes: xlabel='holiday', ylabel='cnt'>

# %%
sns.boxplot(x='yr', y='cnt', data=data, hue='yr')
# Out:
# <Axes: xlabel='yr', ylabel='cnt'>

# %%
intVarlist = ['casual', 'registered', 'cnt']

for var in intVarlist:
    data[var] = data[var].astype('float64')

# %%
data_numeric = data.select_dtypes(include=['float64'])
data_numeric.head()
# Out:
#         temp     atemp      hum  windspeed  casual  registered     cnt
# 0  14.110847  18.18125  80.5833  10.749882   331.0       654.0   985.0
# 1  14.902598  17.68695  69.6087  16.652113   131.0       670.0   801.0
# 2   8.050924   9.47025  43.7273  16.636703   120.0      1229.0  1349.0
# 3   8.200000  10.60610  59.0435  10.739832   108.0      1454.0  1562.0
# 4   9.305237  11.46350  43.6957  12.522300    82.0      1518.0  1600.0

# %%
sns.pairplot(data_numeric)

# %%
corr = data_numeric.corr()
corr
# Out:
#                 temp     atemp       hum  windspeed    casual  registered  \
# temp        1.000000  0.991696  0.128565  -0.158186  0.542731    0.539436
# atemp       0.991696  1.000000  0.141512  -0.183876  0.543362    0.543678
# hum         0.128565  0.141512  1.000000  -0.248506 -0.075211   -0.089212
# windspeed  -0.158186 -0.183876 -0.248506   1.000000 -0.167995   -0.217914
# casual      0.542731  0.543362 -0.075211  -0.167995  1.000000    0.394137
# registered  0.539436  0.543678 -0.089212  -0.217914  0.394137    1.000000
# cnt         0.627044  0.630685 -0.098543  -0.235132  0.672123    0.945411
#
#                  cnt
# temp        0.627044
# atemp       0.630685
# hum        -0.098543
# windspeed  -0.235132
# casual      0.672123
# registered  0.945411
# cnt         1.000000

# %%
mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
sns.heatmap(corr, mask=mask, vmax=1, square=True, annot = True)
# Out:
# <Axes: >

# %%
data.drop(columns=["instant", "dteday", "atemp", "casual", "registered"], inplace=True)
data.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        1           1           2  14.110847
# 1       1   0     1        0        2           1           2  14.902598
# 2       1   0     1        0        3           1           1   8.050924
# 3       1   0     1        0        4           1           1   8.200000
# 4       1   0     1        0        5           1           1   9.305237
#
#        hum  windspeed     cnt
# 0  80.5833  10.749882   985.0
# 1  69.6087  16.652113   801.0
# 2  43.7273  16.636703  1349.0
# 3  59.0435  10.739832  1562.0
# 4  43.6957  12.522300  1600.0

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(data, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
var = ["temp", "hum", "windspeed", "cnt"]

df_train[var] = scaler.fit_transform(df_train[var])
df_test[var] = scaler.transform(df_test[var])

# %%
df_train
# Out:
#      season  yr  mnth  holiday  weekday  workingday  weathersit      temp  \
# 247       3   0     9        1        3           0           2  0.765327
# 335       4   0    12        0        0           0           1  0.317788
# 702       4   1    12        0        3           1           1  0.519232
# 440       1   1     3        0        0           0           2  0.566998
# 136       2   0     5        0        4           1           2  0.626185
# ..      ...  ..   ...      ...      ...         ...         ...       ...
# 71        1   0     3        0        2           1           1  0.405237
# 106       2   0     4        0        2           1           1  0.495350
# 270       4   0     9        0        5           1           2  0.717562
# 435       1   1     3        0        2           1           1  0.507811
# 102       2   0     4        0        5           1           2  0.440316
#
#           hum  windspeed       cnt
# 247  0.814513   0.475900  0.382996
# ...

# %%
df_train.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean     2.546233    0.511986    6.590753    0.032534    3.020548    0.691781
# std      1.104141    0.500285    3.429063    0.177566    1.993881    0.462153
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%      4.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp         hum   windspeed         cnt
# count  584.000000  584.000000  584.000000  584.000000  584.000000
# mean     1.409247    0.551484    0.654151    0.410017    0.520520
# std      0.554399    0.227249    0.146644    0.187249    0.224926
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 584 entries, 247 to 102
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      584 non-null    int64
#  1   yr          584 non-null    int64
#  2   mnth        584 non-null    int64
#  3   holiday     584 non-null    int64
#  4   weekday     584 non-null    int64
#  5   workingday  584 non-null    int64
#  6   weathersit  584 non-null    int64
#  7   temp        584 non-null    float64
#  8   hum         584 non-null    float64
#  9   windspeed   584 non-null    float64
#  10  cnt         584 non-null    float64
# dtypes: float64(4), int64(7)
# memory usage: 54.8 KB

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
X_train = df_train
y_train = df_train.pop("cnt")

# %%
import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train)

lm = sm.OLS(y_train, X_train_lm).fit()

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [ 0.06295983  0.23070641 -0.00585317 -0.09728148  0.00211257 -0.02289779
#  -0.07237154  0.48047798 -0.09554658 -0.12840541] 0.24545599455949824

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     208.5
# Date:                Mon, 30 Mar 2026   Prob (F-statistic):          1.33e-183
# Time:                        22:19:34   Log-Likelihood:                 491.20
# No. Observations:                 584   AIC:                            -960.4
# Df Residuals:                     573   BIC:                            -912.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2455      0.029      8.358      0.000       0.188       0.303
# ...

# %%
X_test = df_test[X_train.columns]
X_test_lm = sm.add_constant(X_test)
y_test = df_test.pop("cnt")
y_pred = lm.predict(X_test_lm)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8442764644694749
